# %%
import requests

# %%
res = requests.get('https://prettyprinted.com')

# %%
print(res)
# Out:
# <Response [200]>

# %%
print(res.headers)
# Out:
# {'Server': 'nginx/1.14.2', 'Date': 'Tue, 14 Apr 2020 21:42:43 GMT', 'Content-Type': 'text/html', 'Last-Modified': 'Fri, 06 Mar 2020 08:00:18 GMT', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'ETag': 'W/"5e620312-2791"', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Encoding': 'gzip'}

# %%
res = requests.get("https://scotch.io")

# %%
print(res.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
#
# <meta http-equiv="X-UA-Compatible" content="ie=edge">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <meta name="mobile-web-app-capable" content="yes">
# <meta name="apple-mobile-web-app-capable" content="yes">
# <meta name="apple-mobile-web-app-status-bar-style" content="black-translucent">
# <title>Top Shelf Web Development Training &#8213; Scotch.io</title>
#
# <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">
# <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png">
# <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png">
# <link rel="manifest" href="/manifest.json">
# <link rel="mask-icon" href="/safari-pinned-tab.svg" color="#2e2e2e">
# <meta name="msapplication-TileColor" content="#2e2e2e">
# <meta name="theme-color" content="#333">
# ...

# %%
API_KEY = "trnsl.1.1.20200414T214858Z.1c55f242534b0e75.a68c2f684840615d30813f2ab598fbcd8cbed420"

# %%
url = "https://translate.yandex.net/api/v1.5/tr.json/translate"

# %%
params = dict(key=API_KEY, text='Hello',lang='en-zh')

# %%
res = requests.get(url,params=params)

# %%
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '{"code":200,"lang":"en-zh","text":["你好"]}'

# %%
print(res.headers)
# Out:
# {'Server': 'nginx/1.6.2', 'Date': 'Tue, 14 Apr 2020 21:53:06 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '45', 'Connection': 'keep-alive', 'Keep-Alive': 'timeout=120', 'X-Content-Type-Options': 'nosniff', 'Request-Uid': '1066494800', 'Request-Text-Size': '5', 'Cache-Control': 'no-store'}

# %%
json=res.json()
print(json)
# Out:
# {'code': 200, 'lang': 'en-zh', 'text': ['你好']}

# %%
type(res.text)
# Out:
# str

# %%
type(res.json())
# Out:
# dict

# %%
print(json['text'][0])
# Out:
# 你好
