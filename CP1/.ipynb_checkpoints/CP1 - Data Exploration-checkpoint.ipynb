# %%
import pandas as pd
import numpy as np
import os
import glob
import json
import sqlite3
from PythonSrc import hdf5_getters
import h5py as hdf

# %%
project_dir = os.getcwd()
msd_subset_data_path=os.path.join(project_dir,'MillionSongSubset/data')
msd_subset_additionalfiles_path=os.path.join(project_dir,'MillionSongSubset/AdditionalFiles')
db_file = os.path.join(msd_subset_additionalfiles_path,'subset_track_metadata.db')

# %%
print(project_dir,msd_subset_data_path,msd_subset_additionalfiles_path)
# Out:
# /Users/jching/Documents/GitHub/Springboard/CP1 /Users/jching/Documents/GitHub/Springboard/CP1/MillionSongSubset/data /Users/jching/Documents/GitHub/Springboard/CP1/MillionSongSubset/AdditionalFiles

# %%
#get all data files for a directory "A"
cnt = 0
testfile_files = []
for root, dirs, files in os.walk(msd_subset_data_path):
    for file in files:
        #print(os.path.join(root,file))
        if ".h5" in file:
            testfile_files.append(os.path.join(msd_subset_data_path,root,file))
        cnt += 1

# %%
len(testfile_files)
# Out:
# 10000

# %%
testfile_files[:10]
# Out:
# ['/Users/jching/Documents/GitHub/Springboard/CP1/MillionSongSubset/data/A/R/R/TRARRZU128F4253CA2.h5',
#  '/Users/jching/Documents/GitHub/Springboard/CP1/MillionSongSubset/data/A/R/R/TRARRJL128F92DED0E.h5',
#  '/Users/jching/Documents/GitHub/Springboard/CP1/MillionSongSubset/data/A/R/R/TRARRUZ128F9307C57.h5',
#  '/Users/jching/Documents/GitHub/Springboard/CP1/MillionSongSubset/data/A/R/R/TRARRWA128F42A0195.h5',
#  '/Users/jching/Documents/GitHub/Springboard/CP1/MillionSongSubset/data/A/R/R/TRARRPG12903CD1DE9.h5',
#  '/Users/jching/Documents/GitHub/Springboard/CP1/MillionSongSubset/data/A/R/R/TRARRER128F9328521.h5',
#  '/Users/jching/Documents/GitHub/Springboard/CP1/MillionSongSubset/data/A/R/R/TRARRYC128F428CCDA.h5',
#  '/Users/jching/Documents/GitHub/Springboard/CP1/MillionSongSubset/data/A/R/R/TRARROY128F42281F7.h5',
#  '/Users/jching/Documents/GitHub/Springboard/CP1/MillionSongSubset/data/A/R/R/TRARREF128F422FD96.h5',
#  '/Users/jching/Documents/GitHub/Springboard/CP1/MillionSongSubset/data/A/R/R/TRARRVB128F92F47CA.h5']

# %%
testfile_1 = str(testfile_files[0])
print(testfile_1)
# Out:
# /Users/jching/Documents/GitHub/Springboard/CP1/MillionSongSubset/data/A/R/R/TRARRZU128F4253CA2.h5

# %%
f = hdf.File(testfile_1, 'r')                                  
#print(f.keys())
print(list(f.keys()))
#artist_name = hdf5_getters.get_artist_name(f)
#artist_name
# Out:
# ['analysis', 'metadata', 'musicbrainz']

# %%
test1 = pd.read_hdf(testfile_1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-158-2020a9c7289b> in <module>
# ----> 1 test1 = pd.read_hdf(testfile_1)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/pytables.py in read_hdf(path_or_buf, key, mode, **kwargs)
#     375             groups = store.groups()
#     376             if len(groups) == 0:
# --> 377                 raise ValueError('No dataset in HDF5 file.')
#     378             candidate_only_group = groups[0]
#     379
#
# ValueError: No dataset in HDF5 file.

# %%
all_artist_names = set()
def func_to_get_artist_name(filename):
    """
    This function does 3 simple things:
    - open the song file
    - get artist ID and put it
    - close the file
    """
    h5 = hdf5_getters.open_h5_file_read(filename)
    artist_name = hdf5_getters.get_artist_name(h5)
    all_artist_names.add(artist_name)
    h5.close()
    
apply_to_all_files(msd_subset_data_path,func=func_to_get_artist_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-139-79c4b9ae0568> in <module>
#      12     h5.close()
#      13
# ---> 14 apply_to_all_files(msd_subset_data_path,func=func_to_get_artist_name)
#
# <ipython-input-42-c8f461116a15> in apply_to_all_files(basedir, func, ext)
#      21         # apply function to all files
#      22         for f in files :
# ---> 23             func(f)
#      24     return cnt
#      25
#
# <ipython-input-139-79c4b9ae0568> in func_to_get_artist_name(filename)
#       7     - close the file
#       8     """
# ----> 9     h5 = hdf5_getters.open_h5_file_read(filename)
#      10     artist_name = hdf5_getters.get_artist_name(h5)
#      11     all_artist_names.add(artist_name)
#
# ~/Documents/GitHub/Springboard/CP1/PythonSrc/hdf5_getters.py in open_h5_file_read(h5filename)
#      37     Same function as in hdf5_utils, here so we avoid one import
#      38     """
# ---> 39     return tables.openFile(h5filename, mode='r')
#      40
#      41
#
# AttributeError: module 'tables' has no attribute 'openFile'

# %%
conn = sqlite3.connect(db_file)
q = "SELECT DISTINCT artist_name FROM songs"
# we query the database
res = conn.execute(q)
all_artist_names_sqlite = res.fetchall()

# %%
all_artist_names_sqlite
# Out:
# [('!!!',),
#  ('(hed) p.e.',),
#  ('089 Clique feat. Minnesota Snipe & Skinny Cueball',),
#  ('089 Clique feat. Prophet',),
#  ('1. Futurologischer Congress',),
#  ('12 Gauge',),
#  ('2 Minutos',),
#  ('2-4 Grooves feat. Reki D.',),
#  ('2-Gether feat. Sarinah',),
#  ('20/20',),
#  ('22-20s',),
#  ('23rd Turnoff',),
#  ('2Fresh',),
#  ('2XL',),
#  ('2raumwohnung',),
#  ('3 Doors Down',),
#  ('3 Steps Ahead',),
#  ('3 Way Funk',),
#  ('3 of Hearts',),
#  ('30 Seconds To Mars',),
#  ('32 Leaves',),
#  ('3OH!3',),
#  ('4 Skins',),
#  ('40 Grit',),
#  ('45 Grave',),
#  ('4Him',),
#  ('5 Blind Boys Of Alabama',),
#  ('50 Cent',),
#  ('50 Cent / Mobb Deep',),
#  ('5th Ward Boyz',),
#  ('6CycleMind',),
#  ('8Ball & MJG',),
#  ('99 Posse',),
#  ('9th Wonder',),
#  ('9th Wonder featuring Defcon_ Phonte',),
#  (':Blacks On :Blondes',),
#  ('A Challenge Of Honour',),
#  ('A Day To Remember',),
#  ('A Different Breed of Killer',),
#  ('A Ghost Devotion',),
#  ('A Perfect Murder',),
#  ('A Skylit Drive',),
#  ('A Static Lullaby',),
#  ('A Tribe Called Quest',),
#  ('A Tundra',),
#  ('A-FS',),
#  ('A-Mei',),
#  ('A-Studio',),
#  ('A.Z.',),
#  ('AFI',),
#  ('AFS',),
#  ('ARRESTED DEVELOPMENT',),
#  ('ATB',),
#  ('AUDIO.3',),
#  ('AZ',),
#  ('Aaron Watson',),
#  ('Abbott & Chambers',),
#  ('Aberdeen',),
#  ('Abijah',),
#  ('Abner Burnette',),
#  ('Abracadabra',),
#  ('Abraham Laboriel',),
#  ('Abrar - Ul - Haq',),
#  ('Abysmal Dawn',),
#  ('Academy/Marriner',),
#  ('Ace Da Vinci',),
#  ('Ace Frehley',),
#  ('Aceyalone',),
#  ('Acorps de Rue',),
#  ('Ada Jane',),
#  ('Adalberto Santiago',),
#  ('Adam Ant',),
#  ('Adam Richman',),
#  ('Adam Richmond',),
#  ('Adolph Hofner',),
#  ('Adr Lavey',),
#  ('Adrenalin O.D.',),
#  ('Adrenaline',),
#  ('Adrienne Pierce',),
#  ('Aeoliah',),
#  ('Aerosmith',),
#  ('Aesop Rock',),
#  ('African Rhythm Messengers',),
#  ('Africando',),
#  ('Africando All Stars',),
#  ('Afrob feat. Sarah',),
#  ('Aftermath',),
#  ('Agency 1.9.9.4',),
#  ('Agnes',),
#  ('Agnostic Front',),
#  ('Ai Ai Ai',),
#  ('Aiden',),
#  ('Aimable',),
#  ('Airto Moreira',),
#  ('Aisha Duo',),
#  ('Akissa',),
#  ('Akon',),
#  ('Akon / Kardinal Offishall',),
#  ('Al De Lory',),
#  ('Al Denson',),
#  ('Al Dexter',),
#  ('Al Di Meola',),
#  ('Al DiMeola',),
#  ('Al Duvall',),
#  ('Al Rapone',),
#  ('Al Toomer',),
#  ('Alacranes Musical',),
#  ('Alain Morisod',),
#  ('Alain Souchon',),
#  ('Alain Turban',),
#  ('Alain-François',),
#  ('Alan Feinberg',),
#  ('Alan Silvestri',),
#  ('Alas',),
#  ('Albert Ayler',),
#  ('Albert Collins',),
#  ('Albert King',),
#  ('Albert Préjean',),
#  ('Alberto Cortez',),
#  ('Albin Myers',),
#  ('Alceu Valença',),
#  ('Ale Möller',),
#  ('Alejandro Lerner',),
#  ('Aleks Syntek',),
#  ('Alex',),
#  ('Alex Fong',),
#  ('Alex Gopher',),
#  ('Alex Theory',),
#  ('Alex Ubago',),
#  ("Alexander O'Neal",),
#  ('Alexander Zonjic',),
#  ('Alexandre Desplat',),
#  ('Alexis HK',),
#  ('Alexisonfire',),
#  ('Alfredo Gutiérrez',),
#  ('Alfredo Kraus',),
#  ('Alfredo Kraus - Orquesta de Conciertos de Madrid - Pablo Sorozábal',),
#  ("Alfredo Kraus/Paul Plishka/Matteo Manuguerra/Sherrill Milnes/Trinity Boys' Choir/Ambrosian Opera Chorus/National Philharmonic Orchestra/James Levine",),
#  ('Alfredo Kraus/Tatiana Troyanos/London Philharmonic Orchestra/Michel Plasson',),
#  ('Alias',),
#  ('Alice Cooper',),
#  ('Alice In Chains',),
#  ('Alice Stuart',),
#  ('Alicia Keys',),
#  ('Alkonost',),
#  ('All Girl Summer Fun Band',),
#  ('All Leather',),
#  ('All Shall Persih',),
#  ('All Time Low',),
#  ('Alphonse Mouzon',),
#  ('Alternative TV',),
#  ('Alturas',),
#  ('Alvin Youngblood Hart',),
#  ('Alvin Youngblood\xa0Hart',),
#  ('Alvino Rey And His Orchestra',),
#  ('Amalia Avgoustaki',),
#  ('Amanajé',),
#  ('Amber Nicholson',),
#  ('Ambient Music Therapy',),
#  ('Amil',),
#  ('Amilcar',),
#  ('Amoral',),
#  ('Amorphis',),
#  ('Amy Lambert',),
#  ('Amy Winehouse',),
#  ('An Cafe',),
#  ('Ana Bekuta',),
#  ('Ana Nikolic',),
#  ('Ana Popovic',),
#  ('Anane',),
#  ('Anané',),
#  ('Anat Ben David',),
#  ('Ancient Astronauts',),
#  ('Andrae Crouch',),
#  ('Andraé Crouch & Solid Gospel',),
#  ('Andre Popp',),
#  ('Andre Verchuren',),
#  ('Andreas Dorau',),
#  ('Andres Calamaro',),
#  ('Andrew W.K.',),
#  ('André Blot',),
#  ('André Minvielle',),
#  ('André Verchuren',),
#  ('Andréa',),
#  ('Andy & Lucas',),
#  ('Andy Andy',),
#  ('Andy Griffith',),
#  ('Andy Russell',),
#  ('Angel Romero',),
#  ('Angel Romero / The Academy of St. Martin in the Fields / Iona Brown',),
#  ('Angela Dimitriou',),
#  ('Angela Lashley',),
#  ('Angela Stewart',),
#  ('Angelica Maria',),
#  ('Angelo Badalamenti',),
#  ('Angelo Badalamenti / Keira Knightley',),
#  ('Angelo Badalamenti / Patrick Wolf',),
#  ('Angels',),
#  ('Angélica María',),
#  ('Angélla Christie',),
#  ('Anita Kerr',),
#  ('Ann Hampton Callaway',),
#  ('Ann Hampton Callaway;Laura Benanti;Michael Gruber;Everett Bradley',),
#  ('Ann Lee',),
#  ('Ann Nesby',),
#  ('Ann Nesby / Jamecia Bennett',),
#  ('Anna Abreu',),
#  ('Anna Meliti',),
#  ('Anna Vissi',),
#  ('Anne Dudley',),
#  ('Anneli Drecker',),
#  ('Annie Blanchard',),
#  ('Annie Lennox',),
#  ('Annie Minogue Band',),
#  ('Annie Philippe',),
#  ('Anthony Blea Y Su Charanga',),
#  ('Anthony Cruz',),
#  ('Anthony Watson',),
#  ('Anti-Flag',),
#  ('Antigone Rising',),
#  ('Antimatter',),
#  ('Antonio Bribiesca',),
#  ('Antonio Koudele',),
#  ('Antonis Remos',),
#  ('Anubis Spire',),
#  ('Apache Indian',),
#  ('Aphasia',),
#  ('April Wine',),
#  ('Aram Shelton',),
#  ('Arc Angels',),
#  ('Archie Bell and The Drells',),
#  ('Architecture In Helsinki',),
#  ('Arco Iris',),
#  ('Arctic Monkeys',),
#  ('Arctique',),
#  ('Arika Kane',),
#  ('Arkona',),
#  ('Army of the Pharoahs',),
#  ('Arne Weise',),
#  ('Arsonists Get All The Girls',),
#  ("Art Blakey's Jazz Messengers",),
#  ('Art Ensemble Of Chicago',),
#  ('Arthur Brown',),
#  ('Arthur Fiedler',),
#  ('Arthur Fiedler;Earl Wild;Pasquale Cardillo',),
#  ('Arthur Tracy',),
#  ('Artie Fishel & The Promised Band',),
#  ('Arturo Sandoval',),
#  ('Asha Puthli',),
#  ('Ashbrg',),
#  ('Ashes to Ashes',),
#  ('Ashton Shepherd',),
#  ('Ashtrax',),
#  ('Asleep At The Wheel',),
#  ('Assassin',),
#  ('Astarte',),
#  ('Asterisk*',),
#  ('Astrovamps',),
#  ('Asure',),
#  ('Aswad',),
#  ('At All Cost',),
#  ('At The Gates',),
#  ('Atari Teenage Riot',),
#  ('Atman',),
#  ('Atom',),
#  ('Atomic Rooster',),
#  ('Atomship',),
#  ('Atreyu',),
#  ('Attack Attack',),
#  ('Audio Adrenaline',),
#  ('Audio Pyper',),
#  ('Auf Der Maur',),
#  ('Aurlus Mabélé',),
#  ('Aurélien Merle',),
#  ('Autonomous Bass Heads',),
#  ('Autumnblaze',),
#  ('Avril',),
#  ('Avril - Remix By Ana Rago',),
#  ('Avril Lavigne',),
#  ('Axe',),
#  ('Aynsley Lister',),
#  ('Ayo',),
#  ('Azis',),
#  ('Azukx',),
#  ('B.A.D.',),
#  ('B.B. King',),
#  ('B.B.King',),
#  ('B.o.B',),
#  ('BB King',),
#  ('BLEED THE SKY',),
#  ('BMX Bandits',),
#  ('BT',),
#  ('BT feat. JES',),
#  ('Babbie Mason',),
#  ('Babbu Maan',),
#  ('Babe Ruth',),
#  ('Baby Bash',),
#  ('Baby Bash / Grimm',),
#  ('Baby D',),
#  ('Baby Grand',),
#  ('Baby Huey & The Baby Sitters',),
#  ('Baby Rasta & Gringo',),
#  ('Babylon Disco',),
#  ('Bacilos',),
#  ('Back Door Slam',),
#  ('Backstreet Boys',),
#  ('Bad Azz',),
#  ('Bad Brains',),
#  ('Bad Company',),
#  ('Bad Religion',),
#  ('Badmarsh & Shri',),
#  ('Bally Sagoo',),
#  ('Bamberg Symphony Orchestra and Hans Swarowsky',),
#  ('Bambino_ Ivan Tirado',),
#  ('Band Of Horses',),
#  ('Banda La Bocana',),
#  ('Bandido',),
#  ('Bangalafumenga',),
#  ('Barbara Carr',),
#  ('Barbara Fairchild',),
#  ('Barbara Jones',),
#  ('Barbara Lusch',),
#  ('Barbara Lynn',),
#  ('Barbarito Diez',),
#  ('Bare Jr.',),
#  ('Barenaked Ladies',),
#  ('Barley Bree',),
#  ('Baroness',),
#  ('Barrabas',),
#  ('Barrio Obrero',),
#  ('Barry Goldberg',),
#  ('Barry Künzel',),
#  ('Barry Manilow',),
#  ('Barry Manilow Featuring The Glenn Miller Orchestra with Debra Byrd',),
#  ('Barry Mann',),
#  ('Bas-Sheva',),
#  ('Basement Jaxx',),
#  ('Basic Channel',),
#  ('BassTurk',),
#  ('Be Bop Deluxe',),
#  ('Beastie Boys',),
#  ('Beat Pharmacy',),
#  ('Beatnuts',),
#  ('Beatnuts featuring Tony Touch',),
#  ('Beatnuts featuring dead prez and Cheryl Pepsi Riley',),
#  ("Beatnuts with Lil' Donny",),
#  ('BeauSoleil',),
#  ('Beautiful Creatures',),
#  ('Beaver Harris',),
#  ('Bebe Winans',),
#  ('Bebe Winans / Stephanie Mills',),
#  ('Bebo & Cigala',),
#  ('Bebo Norman',),
#  ('Becky Baeling',),
#  ('Becoming The Archetype',),
#  ('Bedrock',),
#  ('Bedwetters',),
#  ('Beenie Man',),
#  ('Beenie Man Featuring Janet Jackson',),
#  ('Beenie Man Featuring Wyclef And Redman',),
#  ('Behemoth',),
#  ('Beherit',),
#  ('Bela Fleck And The Flecktones',),
#  ('Belami',),
#  ('Bellatrax feat. Tina Cousins',),
#  ('Belle & Sebastian',),
#  ('Belle and Sebastian',),
#  ('Belphegor',),
#  ('Ben E. King',),
#  ('Ben Harper And The Blind Boys Of Alabama',),
#  ('Ben Jelen',),
#  ('Ben Sidran',),
#  ('Ben Watt feat. Estelle',),
#  ('Benabar',),
#  ('Beneath The Sky',),
#  ('Benga',),
#  ('Benny Spellman',),
#  ('Beogradski Sindikat',),
#  ('Beres Hammond',),
#  ('Beres Hammond Feat. Jah Youth',),
#  ('Beres Hammond Feat. Natural Black',),
#  ('Berlin',),
#  ('Berrogüetto',),
#  ('Bersuit Vergarabat',),
#  ('Bert Kaempfert',),
#  ('Bert Kaempfert And His Orchestra',),
#  ('Bescenta',),
#  ('Bessie Smith',),
#  ('Beth Nielsen Chapman',),
#  ('Betika_ Daouda',),
#  ('Beto Cuevas',),
#  ('Beto y sus Canarios',),
#  ('Between The Buried And Me',),
#  ('Beyoncé',),
#  ('Beyoncé feat. Slim Thug',),
#  ('Biddu',),
#  ('Big Audio Dynamite',),
#  ('Big Daddy Kane',),
#  ('Big Daddy Rick',),
#  ('Big Dee Irwin',),
#  ('Big Jay Oakerson',),
#  ('Big Joe Turner',),
#  ('Big John Greer',),
#  ('Big Mama Thornton with Kansas Bill and his Orchestra',),
#  ('Big Maybelle',),
#  ('Big Mike Griffin',),
#  ('Big Mountain',),
#  ('Big One',),
#  ('Big Rich',),
#  ('Big Rich featuring Devo',),
#  ('Big Rich featuring J. Stalin_ Aristotle',),
#  ('Big Star',),
#  ('BigElf',),
#  ('Bikini Machine',),
#  ('Bill & Gloria Gaither',),
#  ("Bill Boyd's Cowboy Ramblers",),
#  ('Bill Cosby',),
#  ('Bill Douglas',),
#  ('Bill Engvall',),
#  ('Bill Laswell',),
#  ('Bill Murk',),
#  ('Bill Perkins',),
#  ('Bill Perry',),
#  ('Billie Jo Spears',),
#  ('Billie Ray Martin Feat. Ann Peebles',),
#  ('Billy Bragg',),
#  ('Billy Bragg & Wilco',),
#  ('Billy Butler',),
#  ('Billy Higgins',),
#  ('Billy Higgins_ Bob Berg_ Cedar Walton_ Tony Dumas',),
#  ('Billy May & His Orchestra',),
#  ('Billy Murray',),
#  ('Billy Pilgrim',),
#  ('Billy Price_ Fred Chapellier',),
#  ('Billy Walker',),
#  ('Bimbo',),
#  ('Bimbo Band',),
#  ('Bingo Players',),
#  ('Bionikworld',),
#  ('Birdapres',),
#  ('Birds of Prey',),
#  ('Birmingham Jubilee Singers',),
#  ('Bitter End',),
#  ('Bitty McLean',),
#  ('Bizarre Inc',),
#  ('Bizzy Bone',),
#  ('Bizzy Bone Presents',),
#  ('Black Box',),
#  ('Black Debbath',),
#  ('Black Eyed Peas',),
#  ('Black Eyed Peas / Les Nubians / Mos Def',),
#  ('Black Eyed Peas / Terry Dexter',),
#  ('Black Flag',),
#  ('Black History',),
#  ('Black Messiah',),
#  ('Black Sheep',),
#  ('Black Tambourine',),
#  ('Blackalicious',),
#  ('Blackbyrds',),
#  ('Blackfoot',),
#  ('Blanks77',),
#  ('Blessid Union Of Souls',),
#  ('Blind Blake',),
#  ('Blind Blake & The Royal Victoria Hotel Calypsos',),
#  ('Blind Boy Fuller',),
#  ('Blind Lemon Jefferson',),
#  ('Blind Willie Johnson',),
#  ('Blind Willie McTell',),
#  ("Blindman's Sun",),
#  ('Blingtones',),
#  ('Blink-182',),
#  ('Bloc Party',),
#  ('Blondie',),
#  ('Bloomfield',),
#  ('Blue October',),
#  ('Blue Rodeo',),
#  ('Bo Carter',),
#  ('BoDeans',),
#  ('Boards of Canada',),
#  ('Bob Azzam',),
#  ('Bob Carlisle',),
#  ('Bob Cheevers',),
#  ('Bob Crosby',),
#  ('Bob Dylan',),
#  ('Bob Hope',),
#  ('Bob Margolin',),
#  ('Bob Marley',),
#  ('Bob Marley & The Wailers',),
#  ('Bob McKenzie / Doug McKenzie',),
#  ('Bob Neuwirth',),
#  ('Bob Newhart',),
#  ('Bob Sinclar',),
#  ('Bob Willis',),
#  ('Bob Wills',),
#  ('Bobaflex',),
#  ('Bobbie Gentry',),
#  ('Bobby "Blue" Bland',),
#  ('Bobby Bland',),
#  ('Bobby Broom',),
#  ('Bobby Capo',),
#  ('Bobby Darin',),
#  ('Bobby Hutcherson',),
#  ('Bobby Marchan',),
#  ('Bobby Pulido',),
#  ('Bobby Russell',),
#  ('Bobby Valentin',),
#  ('Bobby Vee',),
#  ('Bodies In the Gears of the Apparatus',),
#  ('Bomb Squad',),
#  ('Bombay Rockers',),
#  ('Bon Jovi',),
#  ('Bon Jovi / Ray Davies',),
#  ('Bone Loc',),
#  ('Bone Thugs-N-Harmony',),
#  ('Bone Thugs-N-Harmony / Akon',),
#  ('Boney James And Rick Braun',),
#  ('Bongzilla',),
#  ('Bonita',),
#  ('Bonita & Jerry Cormier',),
#  ('Boogie Pimps',),
#  ('Boogie Pimps Feat. Steve Brookstein',),
#  ('Boondox',),
#  ('Boots Randolph',),
#  ('Borialis',),
#  ('Bottom Of The Hudson',),
#  ('Bounty Killer',),
#  ('Bow Wow Wow',),
#  ('Bowen_ Robin Huw',),
#  ('Boyz II Men',),
#  ('Brainchoke',),
#  ('Brand X',),
#  ('Brasilian Tropical Orchestra',),
#  ('Bravehearts',),
#  ('Bravehearts featuring Nas and Jully Black',),
#  ('Brazilian Tropical Orchestra',),
#  ('Brenda Boykin',),
#  ('Brenda Lee',),
#  ('Brent Lamb',),
#  ("Brian Auger's Oblivion Express",),
#  ('Brian Dullaghan',),
#  ('Brian Eno And David Byrne',),
#  ('Brian Free & Assurance',),
#  ('Brian Keane',),
#  ('Brian Littrell',),
#  ('Brian Tyler',),
#  ('Brice Kapel',),
#  ('Brigada Victor Jara',),
#  ('Britney Spears',),
#  ('Britney Spears feat. Pharrell Williams',),
#  ('Britny Fox',),
#  ('Britt Nicole',),
#  ('Brixx',),
#  ('Broadcast',),
#  ('Brooke Valentine',),
#  ('Brooke White',),
#  ('Brownie McGhee',),
#  ('Bruce BecVar',),
#  ('Bruce Carroll',),
#  ('Bruce Katz Band',),
#  ('Bruce Robison',),
#  ('Bruce Rowland',),
#  ('Bruce Springsteen',),
#  ('Bruford',),
#  ('Bruisers',),
#  ('Bruno Sanfilippo',),
#  ('Bryan Ferry',),
#  ('Bryan White',),
#  ('Bröderna Djup',),
#  ('Buckeye Politicians',),
#  ('Buckwheat Zydeco',),
#  ('Buddy Jewell',),
#  ('Buddy Johnson',),
#  ('Buddy Miles',),
#  ('Buffalo Nickel Band',),
#  ('Bug Mafia',),
#  ('Buju Banton',),
#  ('Bukka White',),
#  ('Bukue One',),
#  ('Bullet For My Valentine',),
#  ('Bullethole',),
#  ('Bumblefoot',),
#  ('Burning Spear',),
#  ('Burt Bacharach',),
#  ('Bury Your Dead',),
#  ('Busdriver',),
#  ('Busdriver featuring Abstract Rude & Ellay Khule',),
#  ('Busta Rhymes',),
#  ('Busta Rhymes feat. Linkin Park',),
#  ('Butterfly Temple',),
#  ('Butthole Surfers',),
#  ('Buzzcocks',),
#  ('Buzzhorn',),
#  ('Buzzov¬"en',),
#  ('Byron Cage featuring Tye Tribbett',),
#  ('Byther Smith',),
#  ('Byzantine',),
#  ('Béla Fleck',),
#  ('Bénabar',),
#  ('Bézu',),
#  ('Bülent Ceylan',),
#  ('C-Side & Petit Mal',),
#  ('C.C. Adcock',),
#  ('C.J. Chenier',),
#  ('C.L. Smooth',),
#  ("CMW - Compton's Most Wanted",),
#  ('Caballo Dorado',),
#  ('Cabas',),
#  ('Cabin Crew',),
#  ('Cachao',),
#  ('Cache Cache',),
#  ('Cactus',),
#  ('Cadacross',),
#  ('Cadet',),
#  ('Café Quijano',),
#  ('Cake',),
#  ('Cal Tjader',),
#  ('Cali',),
#  ('California Oranges',),
#  ('Call To Preserve',),
#  ("Cam'Ron",),
#  ("Cam'Ron / JR Writer",),
#  ("Cam'Ron / Juelz Santana",),
#  ("Cam'Ron / Juelz Santana / Jimmy Jones",),
#  ('Cama',),
#  ('Camerata Brasil',),
#  ('Camp Lo',),
#  ('Cancer Bats',),
#  ('Candlebox',),
#  ('Candy Lo',),
#  ('Caniche Hara-Kiri',),
#  ('Canis Dirus',),
#  ("Cannon's Jug Stompers",),
#  ('Cantara',),
#  ('Capital Tax',),
#  ('Capleton',),
#  ('Capone-N-Noreaga',),
#  ('Capone-N-Noreaga feat. Busta Rhymes and Ron Browz',),
#  ('Captain Beefheart & The Magic Band',),
#  ('Captain Hollywood Project',),
#  ('Caramell',),
#  ('Cardenales del Exito',),
#  ('Cargo Cult',),
#  ('Carl Belew',),
#  ('Carl Cox Vs Yousef',),
#  ('Carl Crack',),
#  ('Carl Davis',),
#  ('Carl Doy',),
#  ('Carl Doy with NZSO',),
#  ('Carl Smith',),
#  ('Carlos Baute',),
#  ('Carlos Embales - Cutumba',),
#  ('Carlos Jimenez',),
#  ('Carlos Jimenez_ J Elvira_ Oliversam',),
#  ('Carlos Nuñez',),
#  ('Carlos Ponce',),
#  ('Carlos Vives',),
#  ('Carlton Livingston',),
#  ('Carman featuring Commissioned & The Christ Church Choir',),
#  ('Carmen Y Laura',),
#  ('Carolyn Arends',),
#  ('Carpenters',),
#  ('Carroll Thompson',),
#  ('Cartel',),
#  ('Casa Bulga',),
#  ('Casey Bill Weldon',),
#  ('Casiotone For The Painfully Alone',),
#  ('Caspa',),
#  ('Caspian',),
#  ('Cass Fox',),
#  ('Cassidy',),
#  ('Cassidy featuring R. Kelly',),
#  ('Cassidy featuring Swizz Beatz',),
#  ('Cassie',),
#  ('Cassius Clay',),
#  ('Casual',),
#  ('Catherine Howe',),
#  ('Catherine Howe & Vo Fletcher',),
#  ('Catherine King/Matthew Schwinghammer/The American Boychoir',),
#  ('Catia Werneck',),
#  ('Cats In Boots',),
#  ('Catupecu Machu',),
#  ('Cauda Pavonis',),
#  ('Cauterize',),
#  ('Cavo',),
#  ('Cece Winans',),
#  ('Cecilia Bartoli / International Chamber Soloists / Orchestra La Scintilla / Adam Fischer',),
#  ('Cedric Gervais Featuring Caroline',),
#  ('Cedric Gervais feat. Second Sun',),
#  ('Cedric Myton',),
#  ('Cerati-Melero',),
#  ('Cesar Camargo Mariano/Helio Delmiro',),
#  ('Chacho',),
#  ('Chaka Demus & Pliers',),
#  ('Chalk Farm',),
#  ('Champion Jack Dupree',),
#  ('Champion Jack Dupree With TS McPhee',),
#  ('Chango Spasiuk',),
#  ('Channel Live',),
#  ('Chanta Vielma',),
#  ('Chantal Chamandy',),
#  ('Chaotica',),
#  ('Chapta_ Stage McCloud_ SupaStarr & Tony Manshino',),
#  ('Charanga Forever',),
#  ('Charanga de la 4',),
#  ('Chariots',),
#  ('Charles Aznavour',),
#  ('Charles Williams',),
#  ('Charles Williams And His Orchestra',),
#  ('Charley Patton',),
#  ('Charley Pride',),
#  ('Charlie Byrd',),
#  ('Charlie Byrd / Carlos Barbosa-Lima / Carlos Barbosa-Lima',),
#  ('Charlie Byrd / Laurindo Almeida',),
#  ('Charlie Byrd Trio',),
#  ('Charlie Cruz',),
#  ('Charlie Haden',),
#  ('Charlie Haden & Chris Anderson',),
#  ('Charlie Khan',),
#  ('Charlie Louvin',),
#  ('Charlie McCoy',),
#  ('Charlie Patton',),
#  ('Charlie Peacock',),
#  ('Charlie Rich',),
#  ('Charlie Walker',),
#  ('Charlotte Gainsbourg',),
#  ('Charly Garcia',),
#  ('Charly García',),
#  ('Chase & Status',),
#  ('Chatelaine',),
#  ('Checkers',),
#  ('Chelsea',),
#  ('Cheo Feliciano',),
#  ('Cheri Keaggy',),
#  ('Cherish The Ladies',),
#  ('Cherrelle',),
#  ('Chet Atkins',),
#  ('Chico',),
#  ('Chico Cesar',),
#  ('Chico Hamilton',),
#  ('Chico Hamilton Quintet',),
#  ('Chimaira',),
#  ('Choir & Great Symphony Orchestra of the All-Union Radio_ N. Shpiller_ S. Krassovsky_ V. Gagarina & N',),
#  ('Chops',),
#  ('Chorus Line',),
#  ('Chris Brown',),
#  ('Chris Camozzi',),
#  ('Chris Clark',),
#  ('Chris Eaton',),
#  ('Chris Farlowe',),
#  ('Chris Jagger',),
#  ('Chris Rea',),
#  ('Chris Rodriguez',),
#  ('Chris Standring',),
#  ('Chris Vickery',),
#  ('Christian McBride',),
#  ('Christian Quast',),
#  ('Christian adam',),
#  ('Christie Hennessy',),
#  ('Christina Aguilera',),
#  ('Christoper Titus',),
#  ('Christophe Beck',),
#  ('Christos Dantis',),
#  ('Christos Kedras',),
#  ('Chroma Key',),
#  ('Chucho Valdés',),
#  ('Chuck Wicks',),
#  ('Chéco Feliciano And Joe King',),
#  ('Ciaran Byrne',),
#  ('Cinder',),
#  ('Cindy Morgan',),
#  ('Circle Jerks',),
#  ('Circular',),
#  ('Cirrus',),
#  ('Citizen Kaned',),
#  ('City High',),
#  ('Claire Elzière',),
#  ('Claire Hamill',),
#  ('Clannad',),
#  ('Clara Nunes',),
#  ('Clarence "Gatemouth" Brown',),
#  ('Clarence Fountain',),
#  ('Clarence Gatemouth Brown',),
#  ('Clarence Profit',),
#  ('Clarisse Lavanant',),
#  ('Claude François',),
#  ('Claudio',),
#  ('Claw Hammer',),
#  ('Clay Crosse',),
#  ('Clementina De Jesus',),
#  ('Click / Click_ M_Ferri',),
#  ('Cliff Bruner',),
#  ('Cliff Edwards/Disney Studio Chorus',),
#  ('Clifton Chenier',),
#  ('Clockwise',),
#  ('Clp',),
#  ('CoCo Lee',),
#  ('Cobra Killer',),
#  ('Cockney Rejects',),
#  ('Coco Montoya',),
#  ('Cocoa Tea',),
#  ('Coffinberry',),
#  ('ColdWorld',),
#  ('Coldplay',),
#  ('Colin James',),
#  ('Colombiafrica - The Mystic Orchestra',),
#  ('Columbia Symphony Orchestra;Igor Stravinsky',),
#  ('Commander Cody & His Lost Planet Airmen',),
#  ('Commander Cody And His Lost Planet Airman',),
#  ('Commander Cody And His Lost Planet Airmen',),
#  ('Commissioned',),
#  ('Computer Paul',),
#  ('Concretes',),
#  ("Confetti's",),
#  ('Conjunto Clasico',),
#  ('Conjunto Mar Azul',),
#  ('Connemara Stone Company',),
#  ('Connie Francis',),
#  ('Connie Smith',),
#  ('Constance Demby',),
#  ('Controlled Dissonance',),
#  ('Converge',),
#  ('Conway Twitty',),
#  ('Cookie Crew',),
#  ('Cookies',),
#  ('Cool Connection',),
#  ('Cool For August',),
#  ('Cool cavemen',),
#  ('Coolio Da Unda Dogg',),
#  ('Coph Nia',),
#  ('Coraleena Ellis',),
#  ('Corb Lund',),
#  ('Corderoy',),
#  ("Corderoy & U4IC DJ'S",),
#  ("Corey / Shaquille O'Neal",),
#  ('Cornel Campbell',),
#  ('Cornell Campbell',),
#  ('Corona',),
#  ('Cotton Candy',),
#  ('Count Ossie',),
#  ('Coven',),
#  ('Cowboy Mouth',),
#  ('Crabby Appleton',),
#  ('Cracker',),
#  ('Cradle Of Filth',),
#  ('Craig Wedren',),
#  ('Crazy Girl',),
#  ('Crazy Horse',),
#  ('Creedence Clearwater Revisited',),
#  ('Creedence Clearwater Revived',),
#  ('Crematorium',),
#  ('Criminal Class USA is Hush Hush Revolution',),
#  ('Cristina Pato - Mutenrohi',),
#  ('Cristy Lane',),
#  ('Cross Country',),
#  ('Crowbar',),
#  ('Crucial Conflict',),
#  ('Crusaders',),
#  ('Crystals',),
#  ('Cumberland Quartet',),
#  ('Cursed',),
#  ('Curt Bois',),
#  ('Curtis',),
#  ('Curtis Mayfield',),
#  ('Cut Copy',),
#  ('Cutting Edge',),
#  ('Cybertribe',),
#  ('Cyndi Wang',),
#  ('Cyril Pahinui',),
#  ('Cândido',),
#  ('Céline Dion',),
#  ('Cómplices',),
#  ("D' Militante",),
#  ("D'Molls",),
#  ('D.A.D.',),
#  ('D.A.R.',),
#  ('D.O.W.N.',),
#  ('D.R.S.',),
#  ('D:Fuse',),
#  ('D:Fuse vs The Scumfrog',),
#  ('DAVE MATTHEWS BAND',),
#  ('DCS',),
#  ('DCX',),
#  ('DJ Clue / Fabolous Sport',),
#  ('DJ Clue / P. Diddy',),
#  ('DJ DLG feat. MC Flipside',),
#  ('DJ Deeon',),
#  ('DJ Dips',),
#  ('DJ Envy',),
#  ('DJ Godfather',),
#  ('DJ Guy',),
#  ('DJ Harry',),
#  ('DJ Icey',),
#  ('DJ Isaac',),
#  ('DJ Nasty',),
#  ('DJ Omega',),
#  ('DJ Ostkurve',),
#  ('DJ Phiene',),
#  ('DJ Primo',),
#  ('DJ Quik',),
#  ('DJ Rashad',),
#  ('DJ Rashad featuring DJ Chi Boogie',),
#  ('DJ Slugo',),
#  ('DJ Spinn',),
#  ('DJ Spinn and DJ Rashad',),
#  ('DJ Spinn featuring Traxman',),
#  ('DJ Taz',),
#  ('DJ Vix',),
#  ('DJ X-Change',),
#  ('DJ X-Change featuring DJ Joey A',),
#  ('DJ X-Change featuring DJ Omega',),
#  ('DJ X-Change featuring Joey A',),
#  ('DMX',),
#  ('DMX / Dyme',),
#  ('DMX / Eve / Jadakiss',),
#  ('DMZ',),
#  ('Daan Junior',),
#  ('Daara J',),
#  ('Daath',),
#  ('Dabbler',),
#  ('Daddy Dog',),
#  ('Daddy Yankee',),
#  ('Daddy Yankee / Bounty Killer',),
#  ('Daddy Yankee / May-Be',),
#  ('Daft Punk',),
#  ('Dakis',),
#  ('Dala',),
#  ('Dale Hawkins',),
#  ('Dale Russ / Finn MacGinty',),
#  ('Daler Mehndi',),
#  ('Daler Mehndi;Chitra',),
#  ('Dallas Holm',),
#  ('Dame Edna Everage with Carl Davis conducting the London Symphony Orchestra and The New Antipodean Singers',),
#  ('Dame Joan Sutherland / New Philharmonia Orchestra / Richard Bonynge',),
#  ('Damita',),
#  ('Damita Jo',),
#  ('Damone',),
#  ('Dan Cummins',),
#  ('Dan Hicks',),
#  ('Dan Moretti',),
#  ('Dan Shen_ Gruppo Vocale Cantemus_ Ensemble Airone_ Luigi Marzola',),
#  ('Dancecore Allstars',),
#  ('Danger Danger',),
#  ('Daniel Chan',),
#  ('Daniel Johnston',),
#  ('Daniel Kobialka',),
#  ('Daniel Paul',),
#  ('Daniela Dessì',),
#  ('Danielle Bollinger',),
#  ('Danilo Perez',),
#  ('Danilo Perez / Claus Ogerman',),
#  ('Dann Huff',),
#  ('Danny Barnes',),
#  ('Danny Davis & The Boys',),
#  ('Danny Diablo feat. Puerto Rican Myke',),
#  ('Danny Elfman',),
#  ('Danny Williams',),
#  ('Danny Wilson',),
#  ('Danny Wright',),
#  ('Daouda',),
#  ('Darcelys',),
#  ('Darden Smith',),
#  ('Dario Marianelli',),
#  ('Dark Distant Spaces',),
#  ('Dark Fortress',),
#  ('Dark Party',),
#  ('Dark Shadows',),
#  ('Dark new Day',),
#  ('Darko',),
#  ('Darryl Worley',),
#  ('Dart',),
#  ('Darwin Hobbs',),
#  ("Darwin's Waiting Room",),
#  ('Daryl Coley',),
#  ('Daryl Coley Featuring the New Generation Singers Reunion Choir',),
#  ('Daryl Hall & John Oates',),
#  ('Daughters',),
#  ('Dave "Baby" Cortez',),
#  ('Dave Alvin',),
#  ('Dave And Ansel Collins',),
#  ('Dave Brockie Experience',),
#  ('Dave Eggar',),
#  ('Dave Graney & Clare Moore',),
#  ('Dave Hollister',),
#  ('Dave Rave_ Mark McCarron',),
#  ('Dave Valentin',),
#  ('Dave Weckl',),
#  ('David & Steve Gordon',),
#  ('David Andreu',),
#  ('David Arkenstone',),
#  ('David Banner',),
#  ('David Banner / Sky / Marcus',),
#  ('David Benoit',),
#  ('David Bowie',),
#  ('David Cook',),
#  ('David Evans',),
#  ('David Gilmour Featuring Richard Wright',),
#  ('David Guetta - Joachim Garraud - Chris Willis',),
#  ('David Hudson',),
#  ('David Jalbert',),
#  ('David Johansen',),
#  ...]
