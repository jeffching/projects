# %%
from sodapy import Socrata
import os

# %%
# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
import pandas as pd
from sodapy import Socrata
client = Socrata("data.seattle.gov","9sjHyhuUrVciAD5BcJeBn3Ysc",username="jchingny@gmail.com",password="D2ta123!")

# %%
results = client.get("rewu-ipqu")

# %%
results_df = pd.DataFrame.from_records(results)

# %%
results_df.shape
# Out:
# (1000, 7)

# %% [markdown]
# results_df.dtypes

# %%
results_df.head(20)
# Out:
#                            business_legal_name            ownership_type  \
# 0                               POOL REBECCA E           Sole Proprietor
# 1                                 JOYFULZI LLC  LLC*Limited Liability Co
# 2                                 JUUL WANDA S           Sole Proprietor
# 3   LENOVA GLOBAL TECHNOLOGY UNITED STATES INC               Corporation
# 4                             WELDY VICTORIA L           Sole Proprietor
# 5                               LUSHER JULIA L           Sole Proprietor
# 6                       WARRANTY LOGISTICS LLC  LLC*Limited Liability Co
# 7                              TELICA PETROS S           Sole Proprietor
# 8                                ZENG JIA MING           Sole Proprietor
# 9                  IONA PRIVATE PROTECTION LLC  LLC*Limited Liability Co
# 10                           MORISSET RONALD A           Sole Proprietor
# 11                                BLAND KAMONI           Sole Proprietor
# ...

# %% [markdown]
# #questions to answer
# For a business seeking to establish a new business, which combination of city, states, and zips have the highest trending popularity
# For example, where should one establish there business if they are in the "El
# what businesses are most popula

# %%
pd.DataFrame(results_df.naics_description.value_counts())
# Out:
# 285
